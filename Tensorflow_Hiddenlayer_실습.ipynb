# %%
# 라이브러리 사용
import tensorflow as tf
import pandas as pd

# %%
# 과거의 데이터 준비
파일경로 = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/boston.csv'
보스턴 = pd.read_csv(파일경로)

# %%
# 독립변수, 종속변수
독립 = 보스턴[['crim', 'zn', 'indus', 'chas', 'nox', 
            'rm', 'age', 'dis', 'rad', 'tax',
            'ptratio', 'b', 'lstat']]
종속 = 보스턴[['medv']]
print(독립.shape, 종속.shape)
# Out:
# (506, 13) (506, 1)

# %%
# 모델의 구조 만들기
X = tf.keras.layers.Input(shape=[13])
H = tf.keras.layers.Dense(10, activation='swish')(X)
Y = tf.keras.layers.Dense(1)(H)
model = tf.keras.models.Model(X, Y)
model.compile(loss='mse')

# %%
# 모델 구조 확인
model.summary()
# Out:
# Model: "functional_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 13)]              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                140
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 11
# =================================================================
# Total params: 151
# Trainable params: 151
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 데이터로 모델 학습(FIT)
model.fit(독립, 종속, epochs=1000, verbose=0)
model.fit(독립, 종속, epochs=10)
# Out:
# Epoch 1/10
# 16/16 [==============================] - 0s 1ms/step - loss: 13.5280
# Epoch 2/10
# 16/16 [==============================] - 0s 1ms/step - loss: 13.0112
# Epoch 3/10
# 16/16 [==============================] - 0s 1ms/step - loss: 12.5774
# Epoch 4/10
# 16/16 [==============================] - 0s 1ms/step - loss: 13.3161
# Epoch 5/10
# 16/16 [==============================] - 0s 1ms/step - loss: 13.4013
# Epoch 6/10
# 16/16 [==============================] - 0s 1ms/step - loss: 12.1024
# Epoch 7/10
# 16/16 [==============================] - 0s 1ms/step - loss: 13.3772
# Epoch 8/10
# 16/16 [==============================] - 0s 1ms/step - loss: 14.0169
# Epoch 9/10
# 16/16 [==============================] - 0s 1ms/step - loss: 12.8088
# Epoch 10/10
# 16/16 [==============================] - 0s 1ms/step - loss: 12.7631

# %%
# 모델 이용
print(model.predict(독립[:5]))
print(종속[:5])
# Out:
# [[32.735447]
#  [23.87138 ]
#  [32.764244]
#  [34.45093 ]
#  [31.901506]]
#    medv
# 0  24.0
# 1  21.6
# 2  34.7
# 3  33.4
# 4  36.2

# %%
################################################################################

# %%
# 과거의 데이터 준비
파일경로 = 'https://raw.githubusercontent.com/blackdew/tensorflow1/master/csv/iris.csv'
아이리스 = pd.read_csv(파일경로)

# %%
# 원핫인코딩
아이리스 = pd.get_dummies(아이리스)

# %%
# 종속변수, 독립변수
독립 = 아이리스[['꽃잎길이', '꽃잎폭', '꽃받침길이', '꽃받침폭']]
종속 = 아이리스[['품종_setosa', '품종_versicolor', '품종_virginica']]
print(독립.shape, 종속.shape)
# Out:
# (150, 4) (150, 3)

# %%
# 모델 구조 만들기
X = tf.keras.layers.Input(shape=[4])
H = tf.keras.layers.Dense(8, activation="swish")(X)
H = tf.keras.layers.Dense(8, activation="swish")(H)
H = tf.keras.layers.Dense(8, activation="swish")(H)
Y = tf.keras.layers.Dense(3, activation='softmax')(H)
model = tf.keras.models.Model(X, Y)
model.compile(loss='categorical_crossentropy',
              metrics='accuracy')

# %%
# 모델 구조 확인
model.summary()
# Out:
# Model: "functional_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 4)]               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 8)                 40
# _________________________________________________________________
# dense_4 (Dense)              (None, 8)                 72
# _________________________________________________________________
# dense_5 (Dense)              (None, 8)                 72
# _________________________________________________________________
# dense_6 (Dense)              (None, 3)                 27
# =================================================================
# Total params: 211
# Trainable params: 211
# Non-trainable params: 0
# _________________________________________________________________

# %%
# 데이터로 모델 학습(FIT)
model.fit(독립, 종속, epochs=100)
# Out:
# Epoch 1/100
# 5/5 [==============================] - 0s 2ms/step - loss: 1.5057 - accuracy: 0.3333
# Epoch 2/100
# 5/5 [==============================] - 0s 2ms/step - loss: 1.2271 - accuracy: 0.3333
# Epoch 3/100
# 5/5 [==============================] - 0s 2ms/step - loss: 1.0815 - accuracy: 0.3333
# Epoch 4/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.9855 - accuracy: 0.3533
# Epoch 5/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.9214 - accuracy: 0.4733
# Epoch 6/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8729 - accuracy: 0.6333
# Epoch 7/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.8332 - accuracy: 0.6667
# Epoch 8/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.7999 - accuracy: 0.6667
# Epoch 9/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.7662 - accuracy: 0.6667
# Epoch 10/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.7347 - accuracy: 0.6667
# Epoch 11/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.7052 - accuracy: 0.6667
# Epoch 12/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6741 - accuracy: 0.6667
# Epoch 13/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6458 - accuracy: 0.7000
# Epoch 14/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.6167 - accuracy: 0.7067
# Epoch 15/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.5922 - accuracy: 0.7400
# Epoch 16/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.5675 - accuracy: 0.7600
# Epoch 17/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.5440 - accuracy: 0.7800
# Epoch 18/100
# 5/5 [==============================] - 0s 1ms/step - loss: 0.5220 - accuracy: 0.8000
# Epoch 19/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.5040 - accuracy: 0.8467
# Epoch 20/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4838 - accuracy: 0.9333
# Epoch 21/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4642 - accuracy: 0.9400
# Epoch 22/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4528 - accuracy: 0.9000
# Epoch 23/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4329 - accuracy: 0.8933
# Epoch 24/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4181 - accuracy: 0.9333
# Epoch 25/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4040 - accuracy: 0.9467
# Epoch 26/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3888 - accuracy: 0.9667
# Epoch 27/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3761 - accuracy: 0.9733
# Epoch 28/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3613 - accuracy: 0.9533
# Epoch 29/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3510 - accuracy: 0.9667
# Epoch 30/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3387 - accuracy: 0.9800
# Epoch 31/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3274 - accuracy: 0.9867
# Epoch 32/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3173 - accuracy: 0.9533
# Epoch 33/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3104 - accuracy: 0.9600
# Epoch 34/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3009 - accuracy: 0.9733
# Epoch 35/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2948 - accuracy: 0.9667
# Epoch 36/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2826 - accuracy: 0.9733
# Epoch 37/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2762 - accuracy: 0.9800
# Epoch 38/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2659 - accuracy: 0.9867
# Epoch 39/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2622 - accuracy: 0.9733
# Epoch 40/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2540 - accuracy: 0.9667
# Epoch 41/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2442 - accuracy: 0.9867
# Epoch 42/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2403 - accuracy: 0.9600
# Epoch 43/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2291 - accuracy: 0.9867
# Epoch 44/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2252 - accuracy: 0.9733
# Epoch 45/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2183 - accuracy: 0.9800
# Epoch 46/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2133 - accuracy: 0.9867
# Epoch 47/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2037 - accuracy: 0.9800
# Epoch 48/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.2009 - accuracy: 0.9733
# Epoch 49/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1996 - accuracy: 0.9733
# Epoch 50/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1913 - accuracy: 0.9800
# Epoch 51/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1938 - accuracy: 0.9733
# Epoch 52/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1809 - accuracy: 0.9867
# Epoch 53/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1768 - accuracy: 0.9867
# Epoch 54/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1753 - accuracy: 0.9667
# Epoch 55/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1697 - accuracy: 0.9800
# Epoch 56/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1649 - accuracy: 0.9800
# Epoch 57/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1644 - accuracy: 0.9867
# Epoch 58/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1629 - accuracy: 0.9733
# Epoch 59/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1650 - accuracy: 0.9733
# Epoch 60/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1529 - accuracy: 0.9800
# Epoch 61/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1496 - accuracy: 0.9800
# Epoch 62/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1490 - accuracy: 0.9867
# Epoch 63/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1485 - accuracy: 0.9800
# Epoch 64/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1470 - accuracy: 0.9867
# Epoch 65/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1437 - accuracy: 0.9800
# Epoch 66/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1390 - accuracy: 0.9800
# Epoch 67/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1405 - accuracy: 0.9733
# Epoch 68/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1369 - accuracy: 0.9867
# Epoch 69/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1337 - accuracy: 0.9800
# Epoch 70/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1351 - accuracy: 0.9667
# Epoch 71/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1271 - accuracy: 0.9800
# Epoch 72/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1254 - accuracy: 0.9800
# Epoch 73/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1275 - accuracy: 0.9733
# Epoch 74/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1237 - accuracy: 0.9800
# Epoch 75/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1227 - accuracy: 0.9867
# Epoch 76/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1255 - accuracy: 0.9667
# Epoch 77/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1237 - accuracy: 0.9733
# Epoch 78/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1161 - accuracy: 0.9867
# Epoch 79/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1163 - accuracy: 0.9733
# Epoch 80/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1116 - accuracy: 0.9800
# Epoch 81/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.1116 - accuracy: 0.9800
# Epoch 82/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1096 - accuracy: 0.9733
# Epoch 83/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1092 - accuracy: 0.9800
# Epoch 84/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1044 - accuracy: 0.9800
# Epoch 85/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1067 - accuracy: 0.9800
# Epoch 86/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1132 - accuracy: 0.9733
# Epoch 87/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1016 - accuracy: 0.9800
# Epoch 88/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1043 - accuracy: 0.9867
# Epoch 89/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1008 - accuracy: 0.9800
# Epoch 90/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0981 - accuracy: 0.9733
# Epoch 91/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0965 - accuracy: 0.9800
# Epoch 92/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0955 - accuracy: 0.9800
# Epoch 93/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0968 - accuracy: 0.9800
# Epoch 94/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.1046 - accuracy: 0.9733
# Epoch 95/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0960 - accuracy: 0.9800
# Epoch 96/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0943 - accuracy: 0.9800
# Epoch 97/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0923 - accuracy: 0.9800
# Epoch 98/100
# 5/5 [==============================] - 0s 3ms/step - loss: 0.0983 - accuracy: 0.9733
# Epoch 99/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0872 - accuracy: 0.9800
# Epoch 100/100
# 5/5 [==============================] - 0s 2ms/step - loss: 0.0939 - accuracy: 0.9867

# %%
# 모델 이용
print(model.predict(독립[:5]))
print(종속[:5])
# Out:
# [[9.9617779e-01 3.8220405e-03 1.0452708e-07]
#  [9.9322432e-01 6.7753037e-03 3.7442248e-07]
#  [9.9501991e-01 4.9798177e-03 2.9348729e-07]
#  [9.9323153e-01 6.7679714e-03 4.6655504e-07]
#  [9.9643034e-01 3.5695147e-03 1.0131206e-07]]
#    품종_setosa  품종_versicolor  품종_virginica
# 0          1              0             0
# 1          1              0             0
# 2          1              0             0
# 3          1              0             0
# 4          1              0             0
